# %% [markdown]
# # LSTM On Earthquake Time Series Data

# %%
import tensorflow as tf
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from enum import Enum
import time

# %%
torch_data_type = torch.float32

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
class FileData:
    def __init__(
        self,
        name,
        acc_index,
        vel_index,
        dsp_index,
        lst_index,
        dt_acc,
        dt_vel,
        dt_dsp,
        unit_acc,
        unit_vel,
        unit_dsp,
        acc_values,
        vel_values,
        dsp_values,
        dt_sampling,
        acc_values_sampled,
        vel_values_sampled,
        dsp_values_sampled,
    ):
        self.name = name
        self.acc_index = acc_index
        self.vel_index = vel_index
        self.dsp_index = dsp_index
        self.lst_index = lst_index
        self.dt_acc = dt_acc
        self.dt_vel = dt_vel
        self.dt_dsp = dt_dsp
        self.unit_acc = unit_acc
        self.unit_vel = unit_vel
        self.unit_dsp = unit_dsp
        self.acc_values = acc_values
        self.vel_values = vel_values
        self.dsp_values = dsp_values
        self.dt_sampling = dt_sampling
        self.acc_values_sampled = acc_values_sampled
        self.vel_values_sampled = vel_values_sampled
        self.dsp_values_sampled = dsp_values_sampled
        self.ID = 0
        self.u_r = None
        self.ud_r = None
        self.udd_r = None
        self.t = None  # time vector

    def __str__(self) -> str:
        return f"{self.name, self.acc_index, self.vel_index, self.dsp_index, self.lst_index, self.dt_acc, self.dt_dsp, self.unit_acc, self.unit_vel, self.unit_dsp, self.acc_values, self.vel_values, self.dsp_values, self.dt_sampling, self.acc_values_sampled, self.vel_values_sampled, self.dsp_values_sampled, self.ID, self.u_r, self.ud_r, self.udd_r, self.t}"

    def __repr__(self) -> str:
        return self.__str__()

# %%
class NormalizationOption(Enum):
    NoScaling = 0
    ScaleShiftStandard = 1
    ScaleShiftAll = 2
    ScaleAll = 3
    ScaleFeatureBased = 4

class TensorsType(Enum):
    Tensorflow = 0
    Torch = 1

class Dataset:
    def __init__(self, filename: str, normalizationOption: NormalizationOption):
      self.data = np.asarray(pd.read_pickle(filename), dtype=object)
      self.normalizationOption = normalizationOption

      self.max_timesteps = max(len(file_data.acc_values_sampled) for file_data in self.data)
      self.min_timesteps = min(len(file_data.acc_values_sampled) for file_data in self.data)

      self.max_abs_acc_input  = max(np.absolute(file_data.acc_values_sampled).max() for file_data in self.data)
      self.max_abs_acc_output = max(np.absolute(file_data.udd_r).max() for file_data in self.data)
      self.max_abs_vel_output = max(np.absolute(file_data.ud_r).max() for file_data in self.data)
      self.max_abs_dsp_output = max(np.absolute(file_data.u_r).max() for file_data in self.data)

      self.max_acc_input  = max(file_data.acc_values_sampled.max() for file_data in self.data)
      self.max_acc_output = max(file_data.udd_r.max() for file_data in self.data)
      self.max_vel_output = max(file_data.ud_r.max() for file_data in self.data)
      self.max_dsp_output = max(file_data.u_r.max() for file_data in self.data)

      self.min_acc_input  = min(file_data.acc_values_sampled.min() for file_data in self.data)
      self.min_acc_output = min(file_data.udd_r.min() for file_data in self.data)
      self.min_vel_output = min(file_data.ud_r.min() for file_data in self.data)
      self.min_dsp_output = min(file_data.u_r.min() for file_data in self.data)

      self.max_abs_all = max([self.max_abs_acc_input, self.max_abs_acc_output, self.max_abs_vel_output, self.max_abs_dsp_output])
      self.max_all     = max([self.max_acc_input, self.max_acc_output, self.max_vel_output, self.max_dsp_output])
      self.min_all     = min([self.min_acc_input, self.min_acc_output, self.min_vel_output, self.min_dsp_output])

      self.start_index=0
      self.end_index=self.min_timesteps
      self.sequence_length=self.end_index - self.start_index
      self.n_earthquakes=len(self.data)

    def print_stats(self):
      print(f'dataset.max_timesteps      {self.max_timesteps     }')
      print(f'dataset.min_timesteps      {self.min_timesteps     }')
      print(f'dataset.max_abs_acc_input  {self.max_abs_acc_input }')
      print(f'dataset.max_abs_acc_output {self.max_abs_acc_output}')
      print(f'dataset.max_abs_vel_output {self.max_abs_vel_output}')
      print(f'dataset.max_abs_dsp_output {self.max_abs_dsp_output}')
      print(f'dataset.max_acc_input      {self.max_acc_input     }')
      print(f'dataset.max_acc_output     {self.max_acc_output    }')
      print(f'dataset.max_vel_output     {self.max_vel_output    }')
      print(f'dataset.max_dsp_output     {self.max_dsp_output    }')
      print(f'dataset.min_acc_input      {self.min_acc_input     }')
      print(f'dataset.min_acc_output     {self.min_acc_output    }')
      print(f'dataset.min_vel_output     {self.min_vel_output    }')
      print(f'dataset.min_dsp_output     {self.min_dsp_output    }')
      print(f'dataset.max_abs_all        {self.max_abs_all       }')
      print(f'dataset.max_all            {self.max_all           }')
      print(f'dataset.min_all            {self.min_all           }')

    def normalize_sequence(self,x,featureIndex=0):
      if self.normalizationOption == NormalizationOption.NoScaling:
        return x
      if self.normalizationOption == NormalizationOption.ScaleShiftStandard:
        min_value = np.min(x)
        max_value = np.max(x)
        return (x - min_value) / (max_value - min_value)
      if self.normalizationOption == NormalizationOption.ScaleShiftAll:
        return (x - self.min_all) / (self.max_all - self.min_all)
      if self.normalizationOption == NormalizationOption.ScaleAll:
        return (x) / (self.max_abs_all)
      if self.normalizationOption == NormalizationOption.ScaleFeatureBased:
        if featureIndex == 0:
          return (x) / max([self.max_abs_acc_input,self.max_abs_acc_output])
        if featureIndex == 2:
          return (x) / self.max_abs_vel_output
        if featureIndex == 1:
          return (x) / self.max_abs_dsp_output

    def rebase_sequence(self,x,featureIndex=0):
      if self.normalizationOption == NormalizationOption.ScaleShiftAll:
        return (x * (self.max_all - self.min_all) +  self.min_all)
      if self.normalizationOption == NormalizationOption.ScaleAll:
        return (x) * (self.max_abs_all)
      if self.normalizationOption == NormalizationOption.ScaleFeatureBased:
        if featureIndex == 0:
          return (x) * max([self.max_abs_acc_input,self.max_abs_acc_output])
        if featureIndex == 2:
          return (x) * self.max_abs_vel_output
        if featureIndex == 1:
          return (x) * self.max_abs_dsp_output

      return x


    def get_ground_acc(self):
      ground_acc = np.zeros((self.n_earthquakes, self.sequence_length))

      for i in range(self.n_earthquakes):
        data = self.data[i]
        acc_data = data.acc_values_sampled[self.start_index:self.end_index]
        ground_acc[i] = self.normalize_sequence(acc_data,0)

      return ground_acc

    def get_response_acc(self):
      response_acc = np.zeros((self.n_earthquakes, self.sequence_length))

      for i in range(self.n_earthquakes):
        data = self.data[i]
        acc_data = data.udd_r[self.start_index:self.end_index]
        response_acc[i] = self.normalize_sequence(acc_data,0)

      return response_acc

    def get_ground_vel(self):
      ground_vel = np.zeros((self.n_earthquakes, self.sequence_length))

      for i in range(self.n_earthquakes):
        data = self.data[i]
        vel_data = data.vel_values_sampled[self.start_index:self.end_index]
        ground_vel[i] = self.normalize_sequence(vel_data,2)

      return ground_vel

    def get_response_vel(self):
      response_vel = np.zeros((self.n_earthquakes, self.sequence_length))

      for i in range(self.n_earthquakes):
        data = self.data[i]
        vel_data = data.ud_r[self.start_index:self.end_index]
        response_vel[i] = self.normalize_sequence(vel_data,2)

      return response_vel

    def get_ground_dsp(self):
      ground_dsp = np.zeros((self.n_earthquakes, self.sequence_length))

      for i in range(self.n_earthquakes):
        data = self.data[i]
        dsp_data = data.dsp_values_sampled[self.start_index:self.end_index]
        ground_dsp[i] = self.normalize_sequence(dsp_data,1)

      return ground_dsp

    def get_response_dsp(self):
      response_dsp = np.zeros((self.n_earthquakes, self.sequence_length))

      for i in range(self.n_earthquakes):
        data = self.data[i]
        dsp_data = data.u_r[self.start_index:self.end_index]
        response_dsp[i] = self.normalize_sequence(dsp_data,1)
      return response_dsp

    def split_data(self,tensorType,n_features,init_zeros):
      x = self.get_ground_acc()
      y1 = self.get_response_acc()
      y2 = self.get_response_dsp()


      if init_zeros > 0 :
        init_zeros_tensor = np.zeros((x.shape[0],init_zeros))
        x=np.concatenate((init_zeros_tensor , x), axis=1)
        y1=np.concatenate((init_zeros_tensor , y1), axis=1)
        y2=np.concatenate((init_zeros_tensor , y2), axis=1)

      x = np.expand_dims(x, axis=2)
      if n_features == 1:
        y = np.expand_dims(y1, axis=2)
      elif n_features == 2:
        y = np.dstack((y1,y2))

      x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.2, random_state = 13)


      if tensorType == TensorsType.Tensorflow:
        x_train_tensor = tf.convert_to_tensor(x_train, dtype=tf.float32)
        x_val_tensor = tf.convert_to_tensor(x_val, dtype=tf.float32)
        y_train_tensor = tf.convert_to_tensor(y_train, dtype=tf.float32)
        y_val_tensor =tf.convert_to_tensor(y_val, dtype=tf.float32)
      elif tensorType == TensorsType.Torch:
        x_train_tensor = torch.from_numpy(x_train).to(torch_data_type)
        x_val_tensor = torch.from_numpy(x_val).to(torch_data_type)
        y_train_tensor = torch.from_numpy(y_train).to(torch_data_type)
        y_val_tensor = torch.from_numpy(y_val).to(torch_data_type)

      return x_train_tensor, x_val_tensor, y_train_tensor, y_val_tensor

# %%
import torch
from torch.utils.data import DataLoader
from torch.utils.data import Dataset as TorchDataset

class TrainingDataset(TorchDataset):
    def __init__(self, inputs, outputs):
        self.inputs = inputs
        self.outputs = outputs

    def __len__(self):
        return len(self.inputs)

    def __getitem__(self, idx):
        return self.inputs[idx], self.outputs[idx]

# %%
def plot_data(sequence1, sequence2, title, xlabel, ylabel, label1="Real", label2="Predicted"):
  x = np.arange(start=0, stop=len(sequence1), step=1) * 0.005 # time step is 0.005

  plt.plot(x, sequence1, label=label1)
  plt.plot(x, sequence2, "--", label=label2)
  plt.title(title)
  plt.xlabel(xlabel)
  plt.ylabel(ylabel)
  plt.legend()
  plt.show()

# %%
dataset = Dataset("/content/drive/MyDrive/DL_Training_Data/all_eq_processed_data_ID_m_SDOF_nonlinear_v003.pickle",NormalizationOption.ScaleFeatureBased)
dataset.print_stats()
# Out:
# dataset.max_timesteps      26799
# dataset.min_timesteps      11201
# dataset.max_abs_acc_input  0.9249152239983484
# dataset.max_abs_acc_output 2.388819770954014
# dataset.max_abs_vel_output 0.2965077324958503
# dataset.max_abs_dsp_output 0.04911199321384019
# dataset.max_acc_input      0.9249152239983484
# dataset.max_acc_output     2.388819770954014
# dataset.max_vel_output     0.26635628566020086
# dataset.max_dsp_output     0.033717489781566023
# dataset.min_acc_input      -0.772271468355947
# dataset.min_acc_output     -1.9476202152885298
# dataset.min_vel_output     -0.2965077324958503
# dataset.min_dsp_output     -0.04911199321384019
# dataset.max_abs_all        2.388819770954014
# dataset.max_all            2.388819770954014
# dataset.min_all            -1.9476202152885298

# %% [markdown]
# Features of interest:
#
# 1 => Acceleration only
#
# 2 => Acceleration and Displacement

# %% [markdown]
# Zeros are inserted at the begining of each sequence to stabilize the model response and avoid overshooting at the begining of response

# %%
n_features_of_interest = 2
n_zeros_at_the_beginning = 2
batch_size = 8
x_train, x_test, y_train, y_test = dataset.split_data(TensorsType.Torch,n_features_of_interest,n_zeros_at_the_beginning)
train_dataloader=torch.utils.data.DataLoader(TrainingDataset(x_train,y_train), batch_size=batch_size, shuffle=False,  num_workers=1)
test_dataloader =torch.utils.data.DataLoader(TrainingDataset(x_test,y_test)  , batch_size=batch_size, shuffle=False,  num_workers=1)

# %%
train_input, train_output_target = next(iter(train_dataloader))
print(f'First input batch shape  {train_input.shape}')
print(f'First output batch shape {train_output_target.shape}')
print(f'First Record Max Scaled Acceleration  = {train_output_target[0,:,0].numpy().max():6.4f}')
print(f'First Record Max Scaled Displacement  = {train_output_target[0,:,1].numpy().max():6.4f}')
print(f'First Record Max Unscaled Acceleration  = {dataset.rebase_sequence(train_output_target[0,:,0].numpy(),0).max():6.4f}')
print(f'First Record Max Unscaled Displacement  = {dataset.rebase_sequence(train_output_target[0,:,1].numpy(),1).max():6.4f}')
# Out:
# First input batch shape  torch.Size([8, 11203, 1])
# First output batch shape torch.Size([8, 11203, 2])
# First Record Max Scaled Acceleration  = 0.1130
# First Record Max Scaled Displacement  = 0.0267
# First Record Max Unscaled Acceleration  = 0.2700
# First Record Max Unscaled Displacement  = 0.0013

# %% [markdown]
# # Defining Model

# %%
DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(DEVICE)
# Out:
# cuda:0

# %%
best_model_path="/content/drive/MyDrive/DL_Training_Data/model_LSTM_Best_029.pt"
last_model_path="/content/drive/MyDrive/DL_Training_Data/model_LSTM_Last_029.pt"

# %%
class StructuralResponseLSTM(nn.Module):
    def __init__(self, input_size, hidden_lstm_size, out_features, num_layers):
        super(StructuralResponseLSTM, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_lstm_size, num_layers=num_layers, bias=True, batch_first=True, dropout=0.0, bidirectional=False, proj_size=0, device=None, dtype=torch_data_type)
        self.linear1 = torch.nn.Linear(hidden_lstm_size, out_features, bias=True, device=None, dtype=torch_data_type)
        # batch_first=True because input data has patch dimension first

    def forward(self, x):
        lstm_output, _ = self.lstm(x)              # (batch_size , sequence length , hidden_lstm_size)
        linear1_output = self.linear1(lstm_output) # (batch_size , sequence length , out_features)
        return linear1_output


floors_number = 1
response_per_floor = n_features_of_interest # acceleration and displacement
input_size = 1 # acceleration
hidden_lstm_size = 128 # Hidden layer size
out_features = floors_number * response_per_floor
num_layers = 1  # Number of layers in LSTM
learning_rate = 0.0001 # 0.001 default


# Initialize the model, loss function, and optimizer
model = StructuralResponseLSTM(input_size, hidden_lstm_size, out_features, num_layers).to(DEVICE)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate, betas=(0.5, 0.999))
loss_values = []

# %%
def train_for_num_epochs(num_epochs):
  st = time.time() # total training start time
  for epoch in range(num_epochs):
      st_e = time.time() # epoch training start time
      epoch_loss = 0
      for inputs, target_outputs in train_dataloader:
          # Forward pass
          outputs = model(inputs.to(DEVICE))
          loss = criterion(outputs, target_outputs.to(DEVICE))
          epoch_loss += loss.item()

          # Backward and optimize
          model.zero_grad()
          loss.backward()
          optimizer.step()

      loss_value = epoch_loss/len(train_dataloader)
      loss_values.append(loss_value)
      et_e = time.time() # epoch training end time
      if loss_value <= min(loss_values):
        torch.save(model.state_dict(), best_model_path)
        print(f'Epoch [{epoch+1:4.0f}/{num_epochs:4.0f}], Loss: {loss_value:.8f} , execution time: {(et_e - st_e)/60:.3f} minutes || New Best ....')
      elif (epoch+1)%50 == 0:
        print(f'Epoch [{epoch+1:4.0f}/{num_epochs:4.0f}], Loss: {loss_value:.8f} , execution time: {(et_e - st_e)/60:.3f} minutes')
  et = time.time() # total training end time
  print(f'Total training execution time: {(et - st)/60:.2f} minutes')
  torch.save(model.state_dict(), last_model_path)

# %%
#train_for_num_epochs(2000)
# Out:
# Epoch [   1/2000], Loss: 0.00256346 , execution time: 0.017 minutes || New Best ....
# Epoch [   2/2000], Loss: 0.00240961 , execution time: 0.009 minutes || New Best ....
# Epoch [   3/2000], Loss: 0.00235212 , execution time: 0.011 minutes || New Best ....
# Epoch [   4/2000], Loss: 0.00233687 , execution time: 0.014 minutes || New Best ....
# Epoch [   5/2000], Loss: 0.00233419 , execution time: 0.016 minutes || New Best ....
# Epoch [   6/2000], Loss: 0.00233384 , execution time: 0.012 minutes || New Best ....
# Epoch [   7/2000], Loss: 0.00233370 , execution time: 0.015 minutes || New Best ....
# Epoch [   8/2000], Loss: 0.00233352 , execution time: 0.017 minutes || New Best ....
# Epoch [   9/2000], Loss: 0.00233332 , execution time: 0.013 minutes || New Best ....
# Epoch [  10/2000], Loss: 0.00233311 , execution time: 0.010 minutes || New Best ....
# Epoch [  11/2000], Loss: 0.00233288 , execution time: 0.009 minutes || New Best ....
# Epoch [  12/2000], Loss: 0.00233265 , execution time: 0.010 minutes || New Best ....
# Epoch [  13/2000], Loss: 0.00233241 , execution time: 0.009 minutes || New Best ....
# Epoch [ 120/2000], Loss: 0.00229597 , execution time: 0.006 minutes || New Best ....
# Epoch [ 121/2000], Loss: 0.00229551 , execution time: 0.006 minutes || New Best ....
# Epoch [ 122/2000], Loss: 0.00229504 , execution time: 0.006 minutes || New Best ....
# Epoch [ 123/2000], Loss: 0.00229458 , execution time: 0.006 minutes || New Best ....
# Epoch [ 124/2000], Loss: 0.00229411 , execution time: 0.006 minutes || New Best ....
# Epoch [ 125/2000], Loss: 0.00229363 , execution time: 0.006 minutes || New Best ....
# Epoch [ 126/2000], Loss: 0.00229316 , execution time: 0.006 minutes || New Best ....
# Epoch [ 127/2000], Loss: 0.00229269 , execution time: 0.006 minutes || New Best ....
# Epoch [ 128/2000], Loss: 0.00229222 , execution time: 0.006 minutes || New Best ....
# Epoch [ 129/2000], Loss: 0.00229174 , execution time: 0.006 minutes || New Best ....
# Epoch [ 130/2000], Loss: 0.00229127 , execution time: 0.006 minutes || New Best ....
# Epoch [ 131/2000], Loss: 0.00229079 , execution time: 0.006 minutes || New Best ....
# Epoch [ 132/2000], Loss: 0.00229032 , execution time: 0.006 minutes || New Best ....
# Epoch [ 133/2000], Loss: 0.00228984 , execution time: 0.006 minutes || New Best ....
# Epoch [ 134/2000], Loss: 0.00228937 , execution time: 0.006 minutes || New Best ....
# Epoch [ 135/2000], Loss: 0.00228890 , execution time: 0.006 minutes || New Best ....
# Epoch [ 136/2000], Loss: 0.00228843 , execution time: 0.006 minutes || New Best ....
# Epoch [ 137/2000], Loss: 0.00228796 , execution time: 0.006 minutes || New Best ....
# Epoch [ 138/2000], Loss: 0.00228750 , execution time: 0.006 minutes || New Best ....
# Epoch [ 139/2000], Loss: 0.00228704 , execution time: 0.006 minutes || New Best ....
# Epoch [ 140/2000], Loss: 0.00228658 , execution time: 0.006 minutes || New Best ....
# Epoch [ 141/2000], Loss: 0.00228613 , execution time: 0.007 minutes || New Best ....
# Epoch [ 142/2000], Loss: 0.00228568 , execution time: 0.008 minutes || New Best ....
# Epoch [ 143/2000], Loss: 0.00228523 , execution time: 0.008 minutes || New Best ....
# Epoch [ 144/2000], Loss: 0.00228479 , execution time: 0.008 minutes || New Best ....
# Epoch [ 145/2000], Loss: 0.00228436 , execution time: 0.008 minutes || New Best ....
# Epoch [ 146/2000], Loss: 0.00228393 , execution time: 0.008 minutes || New Best ....
# Epoch [ 147/2000], Loss: 0.00228351 , execution time: 0.008 minutes || New Best ....
# Epoch [ 148/2000], Loss: 0.00228309 , execution time: 0.008 minutes || New Best ....
# Epoch [ 149/2000], Loss: 0.00228268 , execution time: 0.008 minutes || New Best ....
# Epoch [ 150/2000], Loss: 0.00228228 , execution time: 0.007 minutes || New Best ....
# Epoch [ 151/2000], Loss: 0.00228188 , execution time: 0.007 minutes || New Best ....
# Epoch [ 152/2000], Loss: 0.00228149 , execution time: 0.006 minutes || New Best ....
# Epoch [ 153/2000], Loss: 0.00228110 , execution time: 0.006 minutes || New Best ....
# Epoch [ 154/2000], Loss: 0.00228072 , execution time: 0.006 minutes || New Best ....
# Epoch [ 155/2000], Loss: 0.00228035 , execution time: 0.006 minutes || New Best ....
# Epoch [ 156/2000], Loss: 0.00227999 , execution time: 0.006 minutes || New Best ....
# Epoch [ 157/2000], Loss: 0.00227963 , execution time: 0.006 minutes || New Best ....
# Epoch [ 158/2000], Loss: 0.00227927 , execution time: 0.006 minutes || New Best ....
# Epoch [ 159/2000], Loss: 0.00227893 , execution time: 0.006 minutes || New Best ....
# Epoch [ 160/2000], Loss: 0.00227858 , execution time: 0.006 minutes || New Best ....
# Epoch [ 161/2000], Loss: 0.00227825 , execution time: 0.006 minutes || New Best ....
# Epoch [ 162/2000], Loss: 0.00227791 , execution time: 0.006 minutes || New Best ....
# Epoch [ 163/2000], Loss: 0.00227759 , execution time: 0.006 minutes || New Best ....
# Epoch [ 164/2000], Loss: 0.00227726 , execution time: 0.006 minutes || New Best ....
# Epoch [ 165/2000], Loss: 0.00227695 , execution time: 0.006 minutes || New Best ....
# Epoch [ 166/2000], Loss: 0.00227663 , execution time: 0.006 minutes || New Best ....
# Epoch [ 167/2000], Loss: 0.00227632 , execution time: 0.006 minutes || New Best ....
# Epoch [ 168/2000], Loss: 0.00227602 , execution time: 0.006 minutes || New Best ....
# Epoch [ 169/2000], Loss: 0.00227571 , execution time: 0.006 minutes || New Best ....
# Epoch [ 170/2000], Loss: 0.00227541 , execution time: 0.006 minutes || New Best ....
# Epoch [ 171/2000], Loss: 0.00227512 , execution time: 0.006 minutes || New Best ....
# Epoch [ 172/2000], Loss: 0.00227482 , execution time: 0.006 minutes || New Best ....
# Epoch [ 173/2000], Loss: 0.00227453 , execution time: 0.006 minutes || New Best ....
# Epoch [ 174/2000], Loss: 0.00227424 , execution time: 0.006 minutes || New Best ....
# Epoch [ 175/2000], Loss: 0.00227396 , execution time: 0.006 minutes || New Best ....
# Epoch [ 176/2000], Loss: 0.00227367 , execution time: 0.006 minutes || New Best ....
# Epoch [ 177/2000], Loss: 0.00227339 , execution time: 0.006 minutes || New Best ....
# Epoch [ 178/2000], Loss: 0.00227311 , execution time: 0.007 minutes || New Best ....
# Epoch [ 179/2000], Loss: 0.00227283 , execution time: 0.008 minutes || New Best ....
# Epoch [ 180/2000], Loss: 0.00227255 , execution time: 0.008 minutes || New Best ....
# Epoch [ 181/2000], Loss: 0.00227228 , execution time: 0.008 minutes || New Best ....
# Epoch [ 182/2000], Loss: 0.00227200 , execution time: 0.008 minutes || New Best ....
# Epoch [ 183/2000], Loss: 0.00227173 , execution time: 0.008 minutes || New Best ....
# Epoch [ 184/2000], Loss: 0.00227146 , execution time: 0.008 minutes || New Best ....
# Epoch [ 185/2000], Loss: 0.00227119 , execution time: 0.008 minutes || New Best ....
# Epoch [ 186/2000], Loss: 0.00227092 , execution time: 0.008 minutes || New Best ....
# Epoch [ 187/2000], Loss: 0.00227065 , execution time: 0.007 minutes || New Best ....
# Epoch [ 188/2000], Loss: 0.00227039 , execution time: 0.006 minutes || New Best ....
# Epoch [ 223/2000], Loss: 0.00226111 , execution time: 0.006 minutes || New Best ....
# Epoch [ 224/2000], Loss: 0.00226083 , execution time: 0.006 minutes || New Best ....
# Epoch [ 225/2000], Loss: 0.00226055 , execution time: 0.006 minutes || New Best ....
# Epoch [ 226/2000], Loss: 0.00226026 , execution time: 0.006 minutes || New Best ....
# Epoch [ 227/2000], Loss: 0.00225997 , execution time: 0.006 minutes || New Best ....
# Epoch [ 228/2000], Loss: 0.00225968 , execution time: 0.006 minutes || New Best ....
# Epoch [ 229/2000], Loss: 0.00225939 , execution time: 0.006 minutes || New Best ....
# Epoch [ 230/2000], Loss: 0.00225909 , execution time: 0.006 minutes || New Best ....
# Epoch [ 231/2000], Loss: 0.00225880 , execution time: 0.006 minutes || New Best ....
# Epoch [ 232/2000], Loss: 0.00225849 , execution time: 0.006 minutes || New Best ....
# Epoch [ 233/2000], Loss: 0.00225819 , execution time: 0.006 minutes || New Best ....
# Epoch [ 234/2000], Loss: 0.00225788 , execution time: 0.006 minutes || New Best ....
# Epoch [ 235/2000], Loss: 0.00225756 , execution time: 0.006 minutes || New Best ....
# Epoch [ 236/2000], Loss: 0.00225725 , execution time: 0.006 minutes || New Best ....
# Epoch [ 237/2000], Loss: 0.00225692 , execution time: 0.006 minutes || New Best ....
# Epoch [ 238/2000], Loss: 0.00225660 , execution time: 0.006 minutes || New Best ....
# Epoch [ 239/2000], Loss: 0.00225627 , execution time: 0.006 minutes || New Best ....
# Epoch [ 240/2000], Loss: 0.00225593 , execution time: 0.006 minutes || New Best ....
# Epoch [ 241/2000], Loss: 0.00225559 , execution time: 0.006 minutes || New Best ....
# Epoch [ 242/2000], Loss: 0.00225524 , execution time: 0.006 minutes || New Best ....
# Epoch [ 243/2000], Loss: 0.00225489 , execution time: 0.006 minutes || New Best ....
# Epoch [ 244/2000], Loss: 0.00225453 , execution time: 0.006 minutes || New Best ....
# Epoch [ 245/2000], Loss: 0.00225416 , execution time: 0.006 minutes || New Best ....
# Epoch [ 246/2000], Loss: 0.00225379 , execution time: 0.006 minutes || New Best ....
# Epoch [ 247/2000], Loss: 0.00225341 , execution time: 0.007 minutes || New Best ....
# Epoch [ 248/2000], Loss: 0.00225302 , execution time: 0.008 minutes || New Best ....
# Epoch [ 249/2000], Loss: 0.00225263 , execution time: 0.008 minutes || New Best ....
# Epoch [ 250/2000], Loss: 0.00225222 , execution time: 0.008 minutes || New Best ....
# Epoch [ 251/2000], Loss: 0.00225181 , execution time: 0.008 minutes || New Best ....
# Epoch [ 252/2000], Loss: 0.00225138 , execution time: 0.008 minutes || New Best ....
# Epoch [ 253/2000], Loss: 0.00225095 , execution time: 0.008 minutes || New Best ....
# Epoch [ 254/2000], Loss: 0.00225050 , execution time: 0.008 minutes || New Best ....
# Epoch [ 255/2000], Loss: 0.00225004 , execution time: 0.008 minutes || New Best ....
# Epoch [ 256/2000], Loss: 0.00224957 , execution time: 0.008 minutes || New Best ....
# Epoch [ 257/2000], Loss: 0.00224909 , execution time: 0.006 minutes || New Best ....
# Epoch [ 258/2000], Loss: 0.00224859 , execution time: 0.006 minutes || New Best ....
# Epoch [ 259/2000], Loss: 0.00224808 , execution time: 0.006 minutes || New Best ....
# Epoch [ 260/2000], Loss: 0.00224755 , execution time: 0.006 minutes || New Best ....
# Epoch [ 261/2000], Loss: 0.00224700 , execution time: 0.006 minutes || New Best ....
# Epoch [ 262/2000], Loss: 0.00224643 , execution time: 0.006 minutes || New Best ....
# Epoch [ 263/2000], Loss: 0.00224584 , execution time: 0.006 minutes || New Best ....
# Epoch [ 264/2000], Loss: 0.00224523 , execution time: 0.006 minutes || New Best ....
# Epoch [ 265/2000], Loss: 0.00224460 , execution time: 0.006 minutes || New Best ....
# Epoch [ 266/2000], Loss: 0.00224394 , execution time: 0.007 minutes || New Best ....
# Epoch [ 267/2000], Loss: 0.00224325 , execution time: 0.006 minutes || New Best ....
# Epoch [ 268/2000], Loss: 0.00224254 , execution time: 0.006 minutes || New Best ....
# Epoch [ 269/2000], Loss: 0.00224178 , execution time: 0.006 minutes || New Best ....
# Epoch [ 270/2000], Loss: 0.00224100 , execution time: 0.006 minutes || New Best ....
# Epoch [ 271/2000], Loss: 0.00224017 , execution time: 0.006 minutes || New Best ....
# Epoch [ 272/2000], Loss: 0.00223930 , execution time: 0.006 minutes || New Best ....
# Epoch [ 273/2000], Loss: 0.00223838 , execution time: 0.006 minutes || New Best ....
# Epoch [ 274/2000], Loss: 0.00223740 , execution time: 0.006 minutes || New Best ....
# Epoch [ 275/2000], Loss: 0.00223637 , execution time: 0.006 minutes || New Best ....
# Epoch [ 276/2000], Loss: 0.00223527 , execution time: 0.006 minutes || New Best ....
# Epoch [ 277/2000], Loss: 0.00223409 , execution time: 0.006 minutes || New Best ....
# Epoch [ 278/2000], Loss: 0.00223282 , execution time: 0.006 minutes || New Best ....
# Epoch [ 279/2000], Loss: 0.00223146 , execution time: 0.006 minutes || New Best ....
# Epoch [ 280/2000], Loss: 0.00223000 , execution time: 0.006 minutes || New Best ....
# Epoch [ 281/2000], Loss: 0.00222840 , execution time: 0.006 minutes || New Best ....
# Epoch [ 282/2000], Loss: 0.00222666 , execution time: 0.006 minutes || New Best ....
# Epoch [ 283/2000], Loss: 0.00222474 , execution time: 0.007 minutes || New Best ....
# Epoch [ 284/2000], Loss: 0.00222263 , execution time: 0.008 minutes || New Best ....
# Epoch [ 285/2000], Loss: 0.00222027 , execution time: 0.008 minutes || New Best ....
# Epoch [ 286/2000], Loss: 0.00221760 , execution time: 0.008 minutes || New Best ....
# Epoch [ 287/2000], Loss: 0.00221455 , execution time: 0.008 minutes || New Best ....
# Epoch [ 288/2000], Loss: 0.00221098 , execution time: 0.008 minutes || New Best ....
# Epoch [ 289/2000], Loss: 0.00220670 , execution time: 0.008 minutes || New Best ....
# Epoch [ 290/2000], Loss: 0.00220137 , execution time: 0.008 minutes || New Best ....
# Epoch [ 291/2000], Loss: 0.00219454 , execution time: 0.008 minutes || New Best ....
# Epoch [ 292/2000], Loss: 0.00218546 , execution time: 0.008 minutes || New Best ....
# Epoch [ 293/2000], Loss: 0.00217313 , execution time: 0.006 minutes || New Best ....
# Epoch [ 294/2000], Loss: 0.00215582 , execution time: 0.006 minutes || New Best ....
# Epoch [ 295/2000], Loss: 0.00212680 , execution time: 0.006 minutes || New Best ....
# Epoch [ 296/2000], Loss: 0.00208433 , execution time: 0.006 minutes || New Best ....
# Epoch [ 297/2000], Loss: 0.00206188 , execution time: 0.006 minutes || New Best ....
# Epoch [ 298/2000], Loss: 0.00201248 , execution time: 0.006 minutes || New Best ....
# Epoch [ 299/2000], Loss: 0.00198923 , execution time: 0.006 minutes || New Best ....
# Epoch [ 300/2000], Loss: 0.00228935 , execution time: 0.006 minutes
# Epoch [ 303/2000], Loss: 0.00195353 , execution time: 0.006 minutes || New Best ....
# Epoch [ 304/2000], Loss: 0.00189682 , execution time: 0.006 minutes || New Best ....
# Epoch [ 305/2000], Loss: 0.00187182 , execution time: 0.006 minutes || New Best ....
# Epoch [ 306/2000], Loss: 0.00186813 , execution time: 0.006 minutes || New Best ....
# Epoch [ 307/2000], Loss: 0.00185810 , execution time: 0.006 minutes || New Best ....
# Epoch [ 350/2000], Loss: 0.00213288 , execution time: 0.006 minutes
# Epoch [ 400/2000], Loss: 0.00197917 , execution time: 0.008 minutes
# Epoch [ 408/2000], Loss: 0.00185807 , execution time: 0.006 minutes || New Best ....
# Epoch [ 409/2000], Loss: 0.00184334 , execution time: 0.006 minutes || New Best ....
# Epoch [ 412/2000], Loss: 0.00183318 , execution time: 0.006 minutes || New Best ....
# Epoch [ 413/2000], Loss: 0.00183289 , execution time: 0.006 minutes || New Best ....
# Epoch [ 414/2000], Loss: 0.00182960 , execution time: 0.006 minutes || New Best ....
# Epoch [ 415/2000], Loss: 0.00182360 , execution time: 0.006 minutes || New Best ....
# Epoch [ 416/2000], Loss: 0.00182004 , execution time: 0.006 minutes || New Best ....
# Epoch [ 417/2000], Loss: 0.00181676 , execution time: 0.006 minutes || New Best ....
# Epoch [ 418/2000], Loss: 0.00181356 , execution time: 0.006 minutes || New Best ....
# Epoch [ 419/2000], Loss: 0.00181073 , execution time: 0.006 minutes || New Best ....
# Epoch [ 420/2000], Loss: 0.00180816 , execution time: 0.006 minutes || New Best ....
# Epoch [ 421/2000], Loss: 0.00180583 , execution time: 0.006 minutes || New Best ....
# Epoch [ 422/2000], Loss: 0.00180370 , execution time: 0.007 minutes || New Best ....
# Epoch [ 423/2000], Loss: 0.00180174 , execution time: 0.008 minutes || New Best ....
# Epoch [ 424/2000], Loss: 0.00179994 , execution time: 0.008 minutes || New Best ....
# Epoch [ 425/2000], Loss: 0.00179828 , execution time: 0.008 minutes || New Best ....
# Epoch [ 426/2000], Loss: 0.00179673 , execution time: 0.008 minutes || New Best ....
# Epoch [ 427/2000], Loss: 0.00179528 , execution time: 0.007 minutes || New Best ....
# Epoch [ 428/2000], Loss: 0.00179393 , execution time: 0.008 minutes || New Best ....
# Epoch [ 499/2000], Loss: 0.00176340 , execution time: 0.006 minutes || New Best ....
# Epoch [ 500/2000], Loss: 0.00176306 , execution time: 0.006 minutes || New Best ....
# Epoch [ 501/2000], Loss: 0.00176271 , execution time: 0.006 minutes || New Best ....
# Epoch [ 502/2000], Loss: 0.00176232 , execution time: 0.007 minutes || New Best ....
# Epoch [ 503/2000], Loss: 0.00176192 , execution time: 0.008 minutes || New Best ....
# Epoch [ 504/2000], Loss: 0.00176150 , execution time: 0.008 minutes || New Best ....
# Epoch [ 505/2000], Loss: 0.00176107 , execution time: 0.008 minutes || New Best ....
# Epoch [ 506/2000], Loss: 0.00176062 , execution time: 0.008 minutes || New Best ....
# Epoch [ 507/2000], Loss: 0.00176015 , execution time: 0.008 minutes || New Best ....
# Epoch [ 508/2000], Loss: 0.00175968 , execution time: 0.008 minutes || New Best ....
# Epoch [ 509/2000], Loss: 0.00175920 , execution time: 0.008 minutes || New Best ....
# Epoch [ 510/2000], Loss: 0.00175871 , execution time: 0.008 minutes || New Best ....
# Epoch [ 511/2000], Loss: 0.00175821 , execution time: 0.008 minutes || New Best ....
# Epoch [ 512/2000], Loss: 0.00175771 , execution time: 0.007 minutes || New Best ....
# Epoch [ 513/2000], Loss: 0.00175720 , execution time: 0.006 minutes || New Best ....
# Epoch [ 514/2000], Loss: 0.00175669 , execution time: 0.006 minutes || New Best ....
# Epoch [ 515/2000], Loss: 0.00175618 , execution time: 0.006 minutes || New Best ....
# Epoch [ 516/2000], Loss: 0.00175566 , execution time: 0.006 minutes || New Best ....
# Epoch [ 517/2000], Loss: 0.00175514 , execution time: 0.006 minutes || New Best ....
# Epoch [ 518/2000], Loss: 0.00175462 , execution time: 0.006 minutes || New Best ....
# Epoch [ 519/2000], Loss: 0.00175410 , execution time: 0.006 minutes || New Best ....
# Epoch [ 520/2000], Loss: 0.00175357 , execution time: 0.006 minutes || New Best ....
# Epoch [ 521/2000], Loss: 0.00175305 , execution time: 0.006 minutes || New Best ....
# Epoch [ 522/2000], Loss: 0.00175252 , execution time: 0.006 minutes || New Best ....
# Epoch [ 523/2000], Loss: 0.00175199 , execution time: 0.006 minutes || New Best ....
# Epoch [ 524/2000], Loss: 0.00175147 , execution time: 0.006 minutes || New Best ....
# Epoch [ 525/2000], Loss: 0.00175094 , execution time: 0.006 minutes || New Best ....
# Epoch [ 526/2000], Loss: 0.00175041 , execution time: 0.006 minutes || New Best ....
# Epoch [ 527/2000], Loss: 0.00174988 , execution time: 0.006 minutes || New Best ....
# Epoch [ 528/2000], Loss: 0.00174934 , execution time: 0.006 minutes || New Best ....
# Epoch [ 529/2000], Loss: 0.00174881 , execution time: 0.006 minutes || New Best ....
# Epoch [ 530/2000], Loss: 0.00174828 , execution time: 0.006 minutes || New Best ....
# Epoch [ 531/2000], Loss: 0.00174774 , execution time: 0.006 minutes || New Best ....
# Epoch [ 532/2000], Loss: 0.00174721 , execution time: 0.006 minutes || New Best ....
# Epoch [ 533/2000], Loss: 0.00174667 , execution time: 0.006 minutes || New Best ....
# Epoch [ 534/2000], Loss: 0.00174613 , execution time: 0.006 minutes || New Best ....
# Epoch [ 535/2000], Loss: 0.00174559 , execution time: 0.006 minutes || New Best ....
# Epoch [ 536/2000], Loss: 0.00174505 , execution time: 0.006 minutes || New Best ....
# Epoch [ 537/2000], Loss: 0.00174451 , execution time: 0.006 minutes || New Best ....
# Epoch [ 538/2000], Loss: 0.00174397 , execution time: 0.007 minutes || New Best ....
# Epoch [ 539/2000], Loss: 0.00174342 , execution time: 0.008 minutes || New Best ....
# Epoch [ 540/2000], Loss: 0.00174288 , execution time: 0.008 minutes || New Best ....
# Epoch [ 541/2000], Loss: 0.00174233 , execution time: 0.008 minutes || New Best ....
# Epoch [ 542/2000], Loss: 0.00174178 , execution time: 0.008 minutes || New Best ....
# Epoch [ 543/2000], Loss: 0.00174123 , execution time: 0.008 minutes || New Best ....
# Epoch [ 544/2000], Loss: 0.00174068 , execution time: 0.008 minutes || New Best ....
# Epoch [ 545/2000], Loss: 0.00174012 , execution time: 0.008 minutes || New Best ....
# Epoch [ 546/2000], Loss: 0.00173956 , execution time: 0.008 minutes || New Best ....
# Epoch [ 547/2000], Loss: 0.00173900 , execution time: 0.008 minutes || New Best ....
# Epoch [ 548/2000], Loss: 0.00173844 , execution time: 0.006 minutes || New Best ....
# Epoch [ 549/2000], Loss: 0.00173787 , execution time: 0.006 minutes || New Best ....
# Epoch [ 550/2000], Loss: 0.00173730 , execution time: 0.006 minutes || New Best ....
# Epoch [ 551/2000], Loss: 0.00173673 , execution time: 0.006 minutes || New Best ....
# Epoch [ 552/2000], Loss: 0.00173616 , execution time: 0.006 minutes || New Best ....
# Epoch [ 553/2000], Loss: 0.00173558 , execution time: 0.006 minutes || New Best ....
# Epoch [ 554/2000], Loss: 0.00173500 , execution time: 0.006 minutes || New Best ....
# Epoch [ 555/2000], Loss: 0.00173441 , execution time: 0.007 minutes || New Best ....
# Epoch [ 556/2000], Loss: 0.00173383 , execution time: 0.006 minutes || New Best ....
# Epoch [ 557/2000], Loss: 0.00173323 , execution time: 0.006 minutes || New Best ....
# Epoch [ 558/2000], Loss: 0.00173264 , execution time: 0.006 minutes || New Best ....
# Epoch [ 559/2000], Loss: 0.00173204 , execution time: 0.006 minutes || New Best ....
# Epoch [ 560/2000], Loss: 0.00173143 , execution time: 0.006 minutes || New Best ....
# Epoch [ 561/2000], Loss: 0.00173082 , execution time: 0.006 minutes || New Best ....
# Epoch [ 562/2000], Loss: 0.00173020 , execution time: 0.006 minutes || New Best ....
# Epoch [ 563/2000], Loss: 0.00172958 , execution time: 0.006 minutes || New Best ....
# Epoch [ 564/2000], Loss: 0.00172896 , execution time: 0.006 minutes || New Best ....
# Epoch [ 565/2000], Loss: 0.00172833 , execution time: 0.006 minutes || New Best ....
# Epoch [ 566/2000], Loss: 0.00172769 , execution time: 0.007 minutes || New Best ....
# Epoch [ 567/2000], Loss: 0.00172705 , execution time: 0.006 minutes || New Best ....
# Epoch [ 568/2000], Loss: 0.00172640 , execution time: 0.006 minutes || New Best ....
# Epoch [ 569/2000], Loss: 0.00172575 , execution time: 0.006 minutes || New Best ....
# Epoch [ 570/2000], Loss: 0.00172508 , execution time: 0.006 minutes || New Best ....
# Epoch [ 571/2000], Loss: 0.00172442 , execution time: 0.006 minutes || New Best ....
# Epoch [ 572/2000], Loss: 0.00172374 , execution time: 0.006 minutes || New Best ....
# Epoch [ 573/2000], Loss: 0.00172306 , execution time: 0.006 minutes || New Best ....
# Epoch [ 574/2000], Loss: 0.00172237 , execution time: 0.007 minutes || New Best ....
# Epoch [ 575/2000], Loss: 0.00172167 , execution time: 0.008 minutes || New Best ....
# Epoch [ 576/2000], Loss: 0.00172096 , execution time: 0.008 minutes || New Best ....
# Epoch [ 577/2000], Loss: 0.00172024 , execution time: 0.008 minutes || New Best ....
# Epoch [ 578/2000], Loss: 0.00171952 , execution time: 0.008 minutes || New Best ....
# Epoch [ 579/2000], Loss: 0.00171879 , execution time: 0.008 minutes || New Best ....
# Epoch [ 580/2000], Loss: 0.00171804 , execution time: 0.008 minutes || New Best ....
# Epoch [ 581/2000], Loss: 0.00171729 , execution time: 0.008 minutes || New Best ....
# Epoch [ 582/2000], Loss: 0.00171652 , execution time: 0.008 minutes || New Best ....
# Epoch [ 583/2000], Loss: 0.00171575 , execution time: 0.007 minutes || New Best ....
# Epoch [ 584/2000], Loss: 0.00171496 , execution time: 0.006 minutes || New Best ....
# Epoch [ 585/2000], Loss: 0.00171417 , execution time: 0.006 minutes || New Best ....
# Epoch [ 586/2000], Loss: 0.00171336 , execution time: 0.006 minutes || New Best ....
# Epoch [ 587/2000], Loss: 0.00171254 , execution time: 0.006 minutes || New Best ....
# Epoch [ 588/2000], Loss: 0.00171170 , execution time: 0.006 minutes || New Best ....
# Epoch [ 589/2000], Loss: 0.00171086 , execution time: 0.006 minutes || New Best ....
# Epoch [ 590/2000], Loss: 0.00171000 , execution time: 0.006 minutes || New Best ....
# Epoch [ 591/2000], Loss: 0.00170912 , execution time: 0.006 minutes || New Best ....
# Epoch [ 592/2000], Loss: 0.00170823 , execution time: 0.006 minutes || New Best ....
# Epoch [ 593/2000], Loss: 0.00170733 , execution time: 0.006 minutes || New Best ....
# Epoch [ 594/2000], Loss: 0.00170640 , execution time: 0.006 minutes || New Best ....
# Epoch [ 595/2000], Loss: 0.00170546 , execution time: 0.006 minutes || New Best ....
# Epoch [ 596/2000], Loss: 0.00170451 , execution time: 0.006 minutes || New Best ....
# Epoch [ 597/2000], Loss: 0.00170353 , execution time: 0.006 minutes || New Best ....
# Epoch [ 598/2000], Loss: 0.00170254 , execution time: 0.006 minutes || New Best ....
# Epoch [ 599/2000], Loss: 0.00170153 , execution time: 0.006 minutes || New Best ....
# Epoch [ 600/2000], Loss: 0.00170049 , execution time: 0.006 minutes || New Best ....
# Epoch [ 601/2000], Loss: 0.00169944 , execution time: 0.006 minutes || New Best ....
# Epoch [ 602/2000], Loss: 0.00169836 , execution time: 0.006 minutes || New Best ....
# Epoch [ 603/2000], Loss: 0.00169725 , execution time: 0.006 minutes || New Best ....
# Epoch [ 604/2000], Loss: 0.00169612 , execution time: 0.006 minutes || New Best ....
# Epoch [ 605/2000], Loss: 0.00169497 , execution time: 0.006 minutes || New Best ....
# Epoch [ 606/2000], Loss: 0.00169378 , execution time: 0.006 minutes || New Best ....
# Epoch [ 607/2000], Loss: 0.00169256 , execution time: 0.006 minutes || New Best ....
# Epoch [ 608/2000], Loss: 0.00169132 , execution time: 0.006 minutes || New Best ....
# Epoch [ 609/2000], Loss: 0.00169003 , execution time: 0.007 minutes || New Best ....
# Epoch [ 610/2000], Loss: 0.00168871 , execution time: 0.008 minutes || New Best ....
# Epoch [ 611/2000], Loss: 0.00168735 , execution time: 0.008 minutes || New Best ....
# Epoch [ 612/2000], Loss: 0.00168595 , execution time: 0.008 minutes || New Best ....
# Epoch [ 613/2000], Loss: 0.00168451 , execution time: 0.008 minutes || New Best ....
# Epoch [ 614/2000], Loss: 0.00168301 , execution time: 0.008 minutes || New Best ....
# Epoch [ 615/2000], Loss: 0.00168147 , execution time: 0.008 minutes || New Best ....
# Epoch [ 616/2000], Loss: 0.00167986 , execution time: 0.008 minutes || New Best ....
# Epoch [ 617/2000], Loss: 0.00167820 , execution time: 0.008 minutes || New Best ....
# Epoch [ 618/2000], Loss: 0.00167647 , execution time: 0.008 minutes || New Best ....
# Epoch [ 619/2000], Loss: 0.00167467 , execution time: 0.007 minutes || New Best ....
# Epoch [ 620/2000], Loss: 0.00167279 , execution time: 0.006 minutes || New Best ....
# Epoch [ 621/2000], Loss: 0.00167082 , execution time: 0.006 minutes || New Best ....
# Epoch [ 622/2000], Loss: 0.00166875 , execution time: 0.006 minutes || New Best ....
# Epoch [ 623/2000], Loss: 0.00166658 , execution time: 0.006 minutes || New Best ....
# Epoch [ 624/2000], Loss: 0.00166429 , execution time: 0.006 minutes || New Best ....
# Epoch [ 625/2000], Loss: 0.00166186 , execution time: 0.006 minutes || New Best ....
# Epoch [ 626/2000], Loss: 0.00165929 , execution time: 0.006 minutes || New Best ....
# Epoch [ 627/2000], Loss: 0.00165654 , execution time: 0.006 minutes || New Best ....
# Epoch [ 628/2000], Loss: 0.00165361 , execution time: 0.006 minutes || New Best ....
# Epoch [ 629/2000], Loss: 0.00165046 , execution time: 0.006 minutes || New Best ....
# Epoch [ 630/2000], Loss: 0.00164706 , execution time: 0.006 minutes || New Best ....
# Epoch [ 631/2000], Loss: 0.00164338 , execution time: 0.006 minutes || New Best ....
# Epoch [ 632/2000], Loss: 0.00163939 , execution time: 0.006 minutes || New Best ....
# Epoch [ 633/2000], Loss: 0.00163504 , execution time: 0.006 minutes || New Best ....
# Epoch [ 634/2000], Loss: 0.00163030 , execution time: 0.006 minutes || New Best ....
# Epoch [ 635/2000], Loss: 0.00162513 , execution time: 0.006 minutes || New Best ....
# Epoch [ 636/2000], Loss: 0.00161953 , execution time: 0.006 minutes || New Best ....
# Epoch [ 637/2000], Loss: 0.00161347 , execution time: 0.006 minutes || New Best ....
# Epoch [ 638/2000], Loss: 0.00160697 , execution time: 0.006 minutes || New Best ....
# Epoch [ 639/2000], Loss: 0.00160005 , execution time: 0.006 minutes || New Best ....
# Epoch [ 640/2000], Loss: 0.00159275 , execution time: 0.006 minutes || New Best ....
# Epoch [ 641/2000], Loss: 0.00158512 , execution time: 0.006 minutes || New Best ....
# Epoch [ 642/2000], Loss: 0.00157722 , execution time: 0.006 minutes || New Best ....
# Epoch [ 643/2000], Loss: 0.00156913 , execution time: 0.006 minutes || New Best ....
# Epoch [ 644/2000], Loss: 0.00156099 , execution time: 0.006 minutes || New Best ....
# Epoch [ 645/2000], Loss: 0.00155296 , execution time: 0.007 minutes || New Best ....
# Epoch [ 646/2000], Loss: 0.00154519 , execution time: 0.007 minutes || New Best ....
# Epoch [ 647/2000], Loss: 0.00153772 , execution time: 0.008 minutes || New Best ....
# Epoch [ 648/2000], Loss: 0.00153045 , execution time: 0.008 minutes || New Best ....
# Epoch [ 649/2000], Loss: 0.00152318 , execution time: 0.008 minutes || New Best ....
# Epoch [ 650/2000], Loss: 0.00151576 , execution time: 0.008 minutes || New Best ....
# Epoch [ 651/2000], Loss: 0.00150802 , execution time: 0.008 minutes || New Best ....
# Epoch [ 652/2000], Loss: 0.00149994 , execution time: 0.008 minutes || New Best ....
# Epoch [ 653/2000], Loss: 0.00149126 , execution time: 0.008 minutes || New Best ....
# Epoch [ 654/2000], Loss: 0.00148634 , execution time: 0.008 minutes || New Best ....
# Epoch [ 659/2000], Loss: 0.00147478 , execution time: 0.006 minutes || New Best ....
# Epoch [ 660/2000], Loss: 0.00146297 , execution time: 0.006 minutes || New Best ....
# Epoch [ 666/2000], Loss: 0.00143763 , execution time: 0.006 minutes || New Best ....
# Epoch [ 671/2000], Loss: 0.00141778 , execution time: 0.006 minutes || New Best ....
# Epoch [ 672/2000], Loss: 0.00139594 , execution time: 0.006 minutes || New Best ....
# Epoch [ 679/2000], Loss: 0.00138136 , execution time: 0.006 minutes || New Best ....
# Epoch [ 685/2000], Loss: 0.00136268 , execution time: 0.008 minutes || New Best ....
# Epoch [ 691/2000], Loss: 0.00134692 , execution time: 0.007 minutes || New Best ....
# Epoch [ 692/2000], Loss: 0.00134224 , execution time: 0.006 minutes || New Best ....
# Epoch [ 699/2000], Loss: 0.00131974 , execution time: 0.006 minutes || New Best ....
# Epoch [ 700/2000], Loss: 0.00134900 , execution time: 0.006 minutes
# Epoch [ 705/2000], Loss: 0.00130419 , execution time: 0.006 minutes || New Best ....
# Epoch [ 706/2000], Loss: 0.00130265 , execution time: 0.006 minutes || New Best ....
# Epoch [ 707/2000], Loss: 0.00128732 , execution time: 0.006 minutes || New Best ....
# Epoch [ 713/2000], Loss: 0.00126986 , execution time: 0.006 minutes || New Best ....
# Epoch [ 715/2000], Loss: 0.00125998 , execution time: 0.006 minutes || New Best ....
# Epoch [ 721/2000], Loss: 0.00124427 , execution time: 0.008 minutes || New Best ....
# Epoch [ 729/2000], Loss: 0.00122812 , execution time: 0.006 minutes || New Best ....
# Epoch [ 737/2000], Loss: 0.00122268 , execution time: 0.006 minutes || New Best ....
# Epoch [ 750/2000], Loss: 0.00128355 , execution time: 0.006 minutes
# Epoch [ 759/2000], Loss: 0.00121687 , execution time: 0.008 minutes || New Best ....
# Epoch [ 761/2000], Loss: 0.00120947 , execution time: 0.008 minutes || New Best ....
# Epoch [ 763/2000], Loss: 0.00120573 , execution time: 0.008 minutes || New Best ....
# Epoch [ 765/2000], Loss: 0.00119941 , execution time: 0.006 minutes || New Best ....
# Epoch [ 767/2000], Loss: 0.00119158 , execution time: 0.006 minutes || New Best ....
# Epoch [ 769/2000], Loss: 0.00118751 , execution time: 0.006 minutes || New Best ....
# Epoch [ 771/2000], Loss: 0.00118475 , execution time: 0.006 minutes || New Best ....
# Epoch [ 773/2000], Loss: 0.00118027 , execution time: 0.006 minutes || New Best ....
# Epoch [ 775/2000], Loss: 0.00117705 , execution time: 0.006 minutes || New Best ....
# Epoch [ 777/2000], Loss: 0.00117602 , execution time: 0.006 minutes || New Best ....
# Epoch [ 779/2000], Loss: 0.00117390 , execution time: 0.006 minutes || New Best ....
# Epoch [ 781/2000], Loss: 0.00117086 , execution time: 0.006 minutes || New Best ....
# Epoch [ 783/2000], Loss: 0.00117005 , execution time: 0.006 minutes || New Best ....
# Epoch [ 787/2000], Loss: 0.00116835 , execution time: 0.006 minutes || New Best ....
# Epoch [ 789/2000], Loss: 0.00116605 , execution time: 0.006 minutes || New Best ....
# Epoch [ 791/2000], Loss: 0.00116555 , execution time: 0.007 minutes || New Best ....
# Epoch [ 793/2000], Loss: 0.00116523 , execution time: 0.008 minutes || New Best ....
# Epoch [ 795/2000], Loss: 0.00116201 , execution time: 0.008 minutes || New Best ....
# Epoch [ 797/2000], Loss: 0.00115134 , execution time: 0.008 minutes || New Best ....
# Epoch [ 799/2000], Loss: 0.00111560 , execution time: 0.008 minutes || New Best ....
# Epoch [ 800/2000], Loss: 0.00115917 , execution time: 0.008 minutes
# Epoch [ 801/2000], Loss: 0.00108500 , execution time: 0.007 minutes || New Best ....
# Epoch [ 804/2000], Loss: 0.00102041 , execution time: 0.006 minutes || New Best ....
# Epoch [ 850/2000], Loss: 0.00210380 , execution time: 0.006 minutes
# Epoch [ 900/2000], Loss: 0.00194280 , execution time: 0.006 minutes
# Epoch [ 950/2000], Loss: 0.00173682 , execution time: 0.006 minutes
# Epoch [1000/2000], Loss: 0.00171323 , execution time: 0.006 minutes
# Epoch [1050/2000], Loss: 0.00169703 , execution time: 0.008 minutes
# Epoch [1100/2000], Loss: 0.00167738 , execution time: 0.006 minutes
# Epoch [1150/2000], Loss: 0.00165060 , execution time: 0.006 minutes
# Epoch [1200/2000], Loss: 0.00161378 , execution time: 0.008 minutes
# Epoch [1250/2000], Loss: 0.00155941 , execution time: 0.006 minutes
# Epoch [1300/2000], Loss: 0.00145476 , execution time: 0.006 minutes
# Epoch [1350/2000], Loss: 0.00125524 , execution time: 0.006 minutes
# Epoch [1374/2000], Loss: 0.00100682 , execution time: 0.008 minutes || New Best ....
# Epoch [1375/2000], Loss: 0.00098488 , execution time: 0.008 minutes || New Best ....
# Epoch [1376/2000], Loss: 0.00095983 , execution time: 0.008 minutes || New Best ....
# Epoch [1377/2000], Loss: 0.00093249 , execution time: 0.008 minutes || New Best ....
# Epoch [1378/2000], Loss: 0.00090640 , execution time: 0.008 minutes || New Best ....
# Epoch [1379/2000], Loss: 0.00088332 , execution time: 0.008 minutes || New Best ....
# Epoch [1380/2000], Loss: 0.00086304 , execution time: 0.008 minutes || New Best ....
# Epoch [1381/2000], Loss: 0.00084824 , execution time: 0.008 minutes || New Best ....
# Epoch [1382/2000], Loss: 0.00083548 , execution time: 0.007 minutes || New Best ....
# Epoch [1383/2000], Loss: 0.00081920 , execution time: 0.006 minutes || New Best ....
# Epoch [1384/2000], Loss: 0.00080608 , execution time: 0.006 minutes || New Best ....
# Epoch [1385/2000], Loss: 0.00079534 , execution time: 0.006 minutes || New Best ....
# Epoch [1386/2000], Loss: 0.00077980 , execution time: 0.006 minutes || New Best ....
# Epoch [1387/2000], Loss: 0.00076809 , execution time: 0.006 minutes || New Best ....
# Epoch [1388/2000], Loss: 0.00076088 , execution time: 0.006 minutes || New Best ....
# Epoch [1389/2000], Loss: 0.00074600 , execution time: 0.006 minutes || New Best ....
# Epoch [1390/2000], Loss: 0.00073642 , execution time: 0.006 minutes || New Best ....
# Epoch [1391/2000], Loss: 0.00073638 , execution time: 0.006 minutes || New Best ....
# Epoch [1392/2000], Loss: 0.00071675 , execution time: 0.006 minutes || New Best ....
# Epoch [1393/2000], Loss: 0.00071256 , execution time: 0.006 minutes || New Best ....
# Epoch [1395/2000], Loss: 0.00069579 , execution time: 0.006 minutes || New Best ....
# Epoch [1396/2000], Loss: 0.00069336 , execution time: 0.006 minutes || New Best ....
# Epoch [1400/2000], Loss: 0.00205954 , execution time: 0.006 minutes
# Epoch [1450/2000], Loss: 0.00098080 , execution time: 0.008 minutes
# Epoch [1500/2000], Loss: 0.00081323 , execution time: 0.006 minutes
# Epoch [1550/2000], Loss: 0.00077863 , execution time: 0.006 minutes
# Epoch [1600/2000], Loss: 0.00075210 , execution time: 0.008 minutes
# Epoch [1650/2000], Loss: 0.00073084 , execution time: 0.006 minutes
# Epoch [1685/2000], Loss: 0.00065248 , execution time: 0.006 minutes || New Best ....
# Epoch [1687/2000], Loss: 0.00062900 , execution time: 0.006 minutes || New Best ....
# Epoch [1689/2000], Loss: 0.00062404 , execution time: 0.007 minutes || New Best ....
# Epoch [1691/2000], Loss: 0.00061976 , execution time: 0.006 minutes || New Best ....
# Epoch [1693/2000], Loss: 0.00060842 , execution time: 0.006 minutes || New Best ....
# Epoch [1700/2000], Loss: 0.00070401 , execution time: 0.007 minutes
# Epoch [1704/2000], Loss: 0.00060658 , execution time: 0.008 minutes || New Best ....
# Epoch [1712/2000], Loss: 0.00060114 , execution time: 0.006 minutes || New Best ....
# Epoch [1740/2000], Loss: 0.00057313 , execution time: 0.008 minutes || New Best ....
# Epoch [1743/2000], Loss: 0.00055826 , execution time: 0.008 minutes || New Best ....
# Epoch [1744/2000], Loss: 0.00054689 , execution time: 0.008 minutes || New Best ....
# Epoch [1750/2000], Loss: 0.00081419 , execution time: 0.006 minutes
# Epoch [1762/2000], Loss: 0.00054381 , execution time: 0.006 minutes || New Best ....
# Epoch [1763/2000], Loss: 0.00054380 , execution time: 0.006 minutes || New Best ....
# Epoch [1800/2000], Loss: 0.00119262 , execution time: 0.006 minutes
# Epoch [1823/2000], Loss: 0.00053886 , execution time: 0.006 minutes || New Best ....
# Epoch [1835/2000], Loss: 0.00053311 , execution time: 0.006 minutes || New Best ....
# Epoch [1850/2000], Loss: 0.00083198 , execution time: 0.008 minutes
# Epoch [1854/2000], Loss: 0.00052202 , execution time: 0.006 minutes || New Best ....
# Epoch [1855/2000], Loss: 0.00052127 , execution time: 0.006 minutes || New Best ....
# Epoch [1900/2000], Loss: 0.00056546 , execution time: 0.006 minutes
# Epoch [1950/2000], Loss: 0.00082946 , execution time: 0.007 minutes
# Epoch [1964/2000], Loss: 0.00051866 , execution time: 0.006 minutes || New Best ....
# Epoch [1965/2000], Loss: 0.00050973 , execution time: 0.007 minutes || New Best ....
# Epoch [1985/2000], Loss: 0.00050791 , execution time: 0.006 minutes || New Best ....
# Epoch [2000/2000], Loss: 0.00055524 , execution time: 0.006 minutes
# Total training execution time: 13.54 minutes

# %%
#print(f'Min Loss {min(loss_values):.6f}')
#plt.plot(loss_values)
#plt.show()
# Out:
# Min Loss 0.000508

# %% [markdown]
# # Load Best Model

# %%
best_model = StructuralResponseLSTM(input_size, hidden_lstm_size, out_features, num_layers)#.to(DEVICE)
best_model.load_state_dict(torch.load(best_model_path))
best_model.eval()
# Out:
# StructuralResponseLSTM(
#   (lstm): LSTM(1, 128, batch_first=True)
#   (linear1): Linear(in_features=128, out_features=2, bias=True)
# )

# %% [markdown]
# # Load Last Model

# %%
last_model = StructuralResponseLSTM(input_size, hidden_lstm_size, out_features, num_layers)#.to(DEVICE)
last_model.load_state_dict(torch.load(last_model_path))
last_model.eval()
# Out:
# StructuralResponseLSTM(
#   (lstm): LSTM(1, 128, batch_first=True)
#   (linear1): Linear(in_features=128, out_features=2, bias=True)
# )

# %% [markdown]
# # Inspecting Performance

# %%
from scipy.stats import pearsonr
from math import sqrt
import scipy.fft as ft

def plot_for_index(selected_model,index,x_data,y_data,feature,range=None):
  seq_1 = y_data[index,:,feature].numpy()
  seq_2 = selected_model(x_data[index])[:,feature].detach().numpy()

  seq_1 = dataset.rebase_sequence(seq_1,feature)
  seq_2 = dataset.rebase_sequence(seq_2,feature)

  plot_data_range(seq_1,seq_2 ,"Displacement" if (feature > 0) else "Acceleration", "Time (sec)", "Displacement (m)" if (feature > 0) else "Acceleration (m/s^2)" , "Real" , "Predicted",range)

def plot_data_range(sequence1, sequence2, title, xlabel, ylabel, label1="Real", label2="Predicted", range=None):
  x = np.arange(start=0, stop=len(sequence1), step=1) * 0.005 # time step is 0.005

  plt.plot(x, sequence1, label=label1)
  plt.plot(x, sequence2, "--", label=label2)
  plt.title(title)
  plt.xlabel(xlabel)
  plt.ylabel(ylabel)
  if range != None:
    plt.xlim(range)
  plt.legend()
  plt.show()

def correlation_for_index(selected_model,index,x_data,y_data,feature):
  corr,_ = pearsonr(np.squeeze(selected_model(x_data[index])[:,feature].detach().numpy()), np.squeeze(y_data[index,:,feature].numpy()))
  return corr

def correlation_for_all(selected_model,x_data,y_data,feature):
  corr_coeffs = np.zeros(x_data.shape[0])
  for i in range(x_data.shape[0]):
    corr_coeffs[i] = correlation_for_index(selected_model,i,x_data,y_data,feature)
  return corr_coeffs

def print_correlation_for_all(selected_model,x_data,y_data,feature):
  corr_coeffs = correlation_for_all(selected_model,x_data,y_data,feature)
  for i in range(corr_coeffs.shape[0]):
    print(f'# {i:2.0f} | {corr_coeffs[i]:5.2f}')
  print(f'-----------------------------')
  print(f'max correlation  = {corr_coeffs.max():5.2f}')
  print(f'mean correlation = {np.mean(corr_coeffs):5.2f}')

def plot_cav_for_index(selected_model,index,x_data,y_data,feature):
  seq_1 = y_data[index,:,feature].numpy()
  seq_2 = selected_model(x_data[index])[:,feature].detach().numpy()

  seq_1 = dataset.rebase_sequence(seq_1,feature)
  seq_2 = dataset.rebase_sequence(seq_2,feature)

  seq_1_cav = np.cumsum(np.abs(seq_1))*0.005 # dt
  seq_2_cav = np.cumsum(np.abs(seq_2))*0.005 # dt

  plot_data(seq_1_cav,seq_2_cav ,"CAV", "Time (sec)", "CAV  (m/s)" , "Real" , "Predicted")

def apply_dft(signal_Y,dt,N_f=0,get_half_band=True,UseDecibel=False):
    N_t=len(signal_Y)
    if N_f<1:
        N_f=N_t
    if get_half_band:
        tr_limit= N_f//2
    else:
        tr_limit= N_f

    DFT_X = ft.fft(np.concatenate([signal_Y, np.zeros(N_f-N_t)])) #FFT zero-padded t length K
    phase_X  = np.angle(DFT_X); phase_X  = phase_X[0:tr_limit] / np.pi
    DFT_Amp_X=(2.0/N_t)*np.abs(DFT_X)[0:tr_limit]
    freq_values_X = ft.fftfreq(N_f, dt)[0:tr_limit]
    DFT_X = DFT_X[0:tr_limit]

    if UseDecibel:
        DFT_Amp_X=10*np.log10(DFT_Amp_X)

    return DFT_X,freq_values_X,DFT_Amp_X,phase_X


def plot_dft_for_index(selected_model,index,x_data,y_data,feature):
  seq_1 = y_data[index,:,feature].numpy()
  seq_2 = selected_model(x_data[index])[:,feature].detach().numpy()

  seq_1 = dataset.rebase_sequence(seq_1,feature)
  seq_2 = dataset.rebase_sequence(seq_2,feature)

  dt=0.005
  DFT_1,freq_values_1,DFT_Amp_1,phase_1=apply_dft(seq_1,dt,N_f=0,get_half_band=True)
  DFT_2,freq_values_2,DFT_Amp_2,phase_2=apply_dft(seq_2,dt,N_f=0,get_half_band=True)


  plot_dft_data(freq_values_1,DFT_Amp_1,DFT_Amp_2 ,"DFT", "Frequency (Hz)", "|acc(f)|" , "Real" , "Predicted")

def plot_dft_data(freq_values, sequence1, sequence2,title, xlabel, ylabel, label1="Real", label2="Predicted"):

  plt.plot(freq_values, sequence1, label=label1)
  plt.plot(freq_values, sequence2, "--", label=label2)
  plt.title(title)
  plt.xlabel(xlabel)
  plt.ylabel(ylabel)
  plt.xlim((0,8))
  plt.legend()
  plt.show()

# %% [markdown]
# Correlation for training data (Acceleration)

# %%
print_correlation_for_all(best_model,x_train,y_train,0) #Best Stored Model
# Out:
# #  0 |  0.67
# #  1 |  0.92
# #  2 |  0.91
# #  3 |  0.38
# #  4 |  0.85
# #  5 |  0.63
# #  6 |  0.97
# #  7 |  0.71
# #  8 |  0.91
# #  9 |  0.58
# # 10 |  0.68
# # 11 |  0.89
# # 12 |  0.58
# # 13 |  0.38
# # 14 |  0.87
# # 15 |  0.39
# # 16 |  0.68
# # 17 |  0.54
# # 18 |  0.42
# # 19 |  0.40
# # 20 |  0.43
# # 21 |  0.37
# # 22 |  0.56
# # 23 |  0.28
# # 24 |  0.38
# # 25 |  0.33
# # 26 |  0.69
# # 27 |  0.53
# # 28 |  0.42
# # 29 |  0.86
# # 30 |  0.90
# # 31 |  0.95
# -----------------------------
# max correlation  =  0.97
# mean correlation =  0.63

# %%
print_correlation_for_all(last_model,x_train,y_train,0) #Last Model
# Out:
# #  0 |  0.64
# #  1 |  0.94
# #  2 |  0.90
# #  3 |  0.36
# #  4 |  0.84
# #  5 |  0.58
# #  6 |  0.95
# #  7 |  0.67
# #  8 |  0.89
# #  9 |  0.57
# # 10 |  0.68
# # 11 |  0.86
# # 12 |  0.57
# # 13 |  0.36
# # 14 |  0.83
# # 15 |  0.33
# # 16 |  0.64
# # 17 |  0.53
# # 18 |  0.38
# # 19 |  0.30
# # 20 |  0.38
# # 21 |  0.34
# # 22 |  0.55
# # 23 |  0.26
# # 24 |  0.33
# # 25 |  0.32
# # 26 |  0.68
# # 27 |  0.52
# # 28 |  0.40
# # 29 |  0.82
# # 30 |  0.87
# # 31 |  0.94
# -----------------------------
# max correlation  =  0.95
# mean correlation =  0.60

# %% [markdown]
# Correlation for training data (Displacement)

# %%
print_correlation_for_all(best_model,x_train,y_train,1) #Best Stored Model
# Out:
# #  0 |  0.32
# #  1 |  0.73
# #  2 |  0.86
# #  3 |  0.13
# #  4 |  0.84
# #  5 |  0.45
# #  6 |  0.82
# #  7 |  0.53
# #  8 |  0.90
# #  9 |  0.20
# # 10 |  0.03
# # 11 |  0.85
# # 12 |  0.38
# # 13 |  0.09
# # 14 |  0.84
# # 15 |  0.39
# # 16 |  0.65
# # 17 |  0.07
# # 18 |  0.28
# # 19 |  0.50
# # 20 |  0.23
# # 21 |  0.21
# # 22 |  0.27
# # 23 |  0.10
# # 24 |  0.38
# # 25 |  0.08
# # 26 |  0.31
# # 27 |  0.15
# # 28 |  0.06
# # 29 |  0.87
# # 30 |  0.83
# # 31 |  0.87
# -----------------------------
# max correlation  =  0.90
# mean correlation =  0.44

# %%
print_correlation_for_all(last_model,x_train,y_train,1) #Last Model
# Out:
# #  0 |  0.25
# #  1 |  0.77
# #  2 |  0.86
# #  3 |  0.11
# #  4 |  0.84
# #  5 |  0.37
# #  6 |  0.80
# #  7 |  0.44
# #  8 |  0.90
# #  9 |  0.15
# # 10 |  0.03
# # 11 |  0.82
# # 12 |  0.29
# # 13 |  0.06
# # 14 |  0.79
# # 15 |  0.32
# # 16 |  0.60
# # 17 |  0.04
# # 18 |  0.21
# # 19 |  0.38
# # 20 |  0.14
# # 21 |  0.16
# # 22 |  0.24
# # 23 |  0.06
# # 24 |  0.31
# # 25 |  0.06
# # 26 |  0.24
# # 27 |  0.09
# # 28 |  0.04
# # 29 |  0.83
# # 30 |  0.77
# # 31 |  0.86
# -----------------------------
# max correlation  =  0.90
# mean correlation =  0.40

# %% [markdown]
# Correlation for testing data (Acceleration)

# %%
print_correlation_for_all(best_model,x_test,y_test,0)#Best Stored Model
# Out:
# #  0 |  0.38
# #  1 |  0.45
# #  2 |  0.69
# #  3 |  0.93
# #  4 |  0.34
# #  5 |  0.56
# #  6 |  0.40
# #  7 |  0.61
# -----------------------------
# max correlation  =  0.93
# mean correlation =  0.55

# %%
print_correlation_for_all(last_model,x_test,y_test,0)#Last Model
# Out:
# #  0 |  0.37
# #  1 |  0.43
# #  2 |  0.66
# #  3 |  0.92
# #  4 |  0.32
# #  5 |  0.54
# #  6 |  0.39
# #  7 |  0.60
# -----------------------------
# max correlation  =  0.92
# mean correlation =  0.53

# %% [markdown]
# Correlation for testing data (Displacement)

# %%
print_correlation_for_all(best_model,x_test,y_test,1)#Best Stored Model
# Out:
# #  0 |  0.10
# #  1 | -0.07
# #  2 |  0.42
# #  3 |  0.84
# #  4 |  0.07
# #  5 |  0.08
# #  6 | -0.06
# #  7 |  0.21
# -----------------------------
# max correlation  =  0.84
# mean correlation =  0.20

# %%
print_correlation_for_all(last_model,x_test,y_test,1)#Last Model
# Out:
# #  0 |  0.05
# #  1 | -0.04
# #  2 |  0.33
# #  3 |  0.84
# #  4 |  0.04
# #  5 |  0.05
# #  6 | -0.06
# #  7 |  0.18
# -----------------------------
# max correlation  =  0.84
# mean correlation =  0.17

# %% [markdown]
# # Training Samples

# %%
plot_for_index(best_model,31,x_train,y_train,0)

# %%
plot_for_index(best_model,31,x_train,y_train,1)

# %%
plot_for_index(best_model,31,x_train,y_train,1,(20,30))

# %%
plot_cav_for_index(best_model,31,x_train,y_train,0)

# %%
plot_dft_for_index(best_model,31,x_train,y_train,0)

# %% [markdown]
# # Testing Samples

# %%
plot_for_index(best_model,3,x_test,y_test,0)
plot_for_index(best_model,3,x_test,y_test,0,(10,20))

# %%
plot_for_index(best_model,3,x_test,y_test,1)
plot_for_index(best_model,3,x_test,y_test,1,(10,20))

# %%
plot_cav_for_index(best_model,3,x_test,y_test,0)

# %%
plot_dft_for_index(best_model,3,x_test,y_test,0)

# %% [markdown]
# # End of testing
